# %% [markdown]
# <a href="https://colab.research.google.com/github/NileshCT/Model_pickling_Classification_task/blob/main/Pickling_On_Classification_Modelling_WeatherAUS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing required libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/drive/MyDrive/weatherAUS.csv.zip")

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.tail()
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %% [markdown]
# Dropping unwanted feature from dataframe.

# %%
df.drop(["Date"],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6          NaN       NaN           W
# 1   Albury      7.4     25.1       0.0          NaN       NaN         WNW
# 2   Albury     12.9     25.7       0.0          NaN       NaN         WSW
# 3   Albury      9.2     28.0       0.0          NaN       NaN          NE
# 4   Albury     17.5     32.3       1.0          NaN       NaN           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0           44.0          W        WNW  ...         71.0         22.0
# 1           44.0        NNW        WSW  ...         44.0         25.0
# 2           46.0          W        WSW  ...         38.0         30.0
# 3           24.0         SE          E  ...         45.0         16.0
# 4           41.0        ENE         NW  ...         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.dtypes
# Out:
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %% [markdown]
# Exploring the numeric and categorical feature separatly.

# %%
numeric_columns=df.describe().columns
numeric_columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm'],
#       dtype='object')

# %%
categorical_feature=df.describe(include=object).columns
categorical_feature
# Out:
# Index(['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday',
#        'RainTomorrow'],
#       dtype='object')

# %%
df1=df.copy()

# %% [markdown]
# separating training and inferencial data.

# %%
# It looks like you’re working with a Pandas DataFrame and trying to find the indices of rows 
# where the “RainTomorrow” column has missing values.
a=[(i,index) for i,index in enumerate(df["RainTomorrow"]) if pd.isna(index)]
result = pd.DataFrame(a).set_index(0)

# %%
t=pd.DataFrame(a).set_index(0)
t.head()
# Out:
#       1
# 0
# 14  NaN
# 283 NaN
# 435 NaN
# 437 NaN
# 443 NaN

# %%
index_nan=t.index.tolist()
index_nan
# Out:
# [14,
#  283,
#  435,
#  437,
#  443,
#  452,
#  455,
#  464,
#  611,
#  983,
#  984,
#  985,
#  986,
#  1013,
#  1374,
#  1529,
#  1530,
#  1531,
#  1685,
#  1922,
#  2031,
#  2032,
#  2033,
#  2042,
#  2913,
#  2934,
#  2942,
#  2943,
#  2944,
#  3201,
#  3211,
#  3316,
#  3338,
#  3339,
#  3384,
#  3411,
#  3412,
#  3428,
#  3433,
#  3438,
#  3446,
#  3447,
#  3452,
#  3457,
#  3462,
#  3471,
#  3472,
#  3482,
#  3517,
#  3524,
#  3525,
#  3526,
#  3529,
#  3530,
#  3532,
#  3539,
#  3542,
#  3549,
#  3552,
#  3576,
#  3584,
#  3595,
#  3629,
#  3634,
#  3639,
#  3692,
#  3760,
#  3955,
#  4044,
#  4050,
#  4131,
#  4344,
#  4345,
#  4629,
#  4644,
#  4656,
#  4845,
#  4900,
#  4911,
#  4912,
#  4935,
#  4938,
#  4939,
#  5056,
#  5079,
#  5149,
#  5393,
#  5458,
#  5459,
#  5460,
#  5461,
#  5462,
#  5841,
#  5842,
#  5843,
#  5844,
#  5845,
#  5846,
#  5847,
#  5848,
#  5849,
#  5850,
#  5851,
#  5852,
#  5853,
#  5854,
#  5855,
#  5856,
#  5857,
#  5876,
#  6294,
#  6968,
# ...

# %%
df1_inference=df1.iloc[index_nan]
df1_inference
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 14       Albury      8.4     24.6       0.0          NaN       NaN
# 283      Albury      2.6      NaN       0.0          NaN       NaN
# 435      Albury     22.1     35.1       0.0          NaN       NaN
# 437      Albury     21.5     35.0       0.0          NaN       NaN
# 443      Albury     15.5     30.6       0.0          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 144955    Uluru     22.5     37.7       0.0          NaN       NaN
# 145091    Uluru     12.3     19.1       0.0          NaN       NaN
# 145092    Uluru     14.2     18.7       NaN          NaN       NaN
# 145335    Uluru     13.5      NaN       0.0          NaN       NaN
# 145459    Uluru     14.9      NaN       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 14             NaN            NaN          S        WNW  ...         57.0
# ...

# %%
t.shape
# Out:
# (3267, 1)

# %%
#Creating list of all non null values in the target variable for spliting in train and test data.
a=[]
for i in range(df1.shape[0]):
  if i not in index_nan:
    a.append(i)

# %%
df1_training_data=df1.iloc[a]
df1_training_data
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Albury     13.4     22.9       0.6          NaN       NaN
# 1        Albury      7.4     25.1       0.0          NaN       NaN
# 2        Albury     12.9     25.7       0.0          NaN       NaN
# 3        Albury      9.2     28.0       0.0          NaN       NaN
# 4        Albury     17.5     32.3       1.0          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 145454    Uluru      3.5     21.8       0.0          NaN       NaN
# 145455    Uluru      2.8     23.4       0.0          NaN       NaN
# 145456    Uluru      3.6     25.3       0.0          NaN       NaN
# 145457    Uluru      5.4     26.9       0.0          NaN       NaN
# 145458    Uluru      7.8     27.0       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0                W           44.0          W        WNW  ...         71.0
# ...

# %% [markdown]
# Spliting training data into two different dependant and independant feature.

# %%
X_training_data=df1_training_data.drop("RainTomorrow",axis=1)
y_training_data=df1_training_data["RainTomorrow"]

# %%
X_training_data=X_training_data.fillna(method="ffill",axis=0)
X_training_data=X_training_data.fillna(method="bfill",axis=0)

# %% [markdown]
# Converting the categorical records into numeric feature.

# %%
from sklearn import preprocessing
L_encoding=preprocessing.LabelEncoder()
X_training_data["Location"]=L_encoding.fit_transform(X_training_data["Location"])

# %%
X_training_data["WindGustDir"]=L_encoding.fit_transform(X_training_data["WindGustDir"])

# %%
X_training_data["WindDir9am"]=L_encoding.fit_transform(X_training_data["WindDir9am"])

# %%
X_training_data["WindDir3pm"]=L_encoding.fit_transform(X_training_data["WindDir3pm"])

# %%
X_training_data["RainToday"]=L_encoding.fit_transform(X_training_data["RainToday"])

# %%
X_training_data.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         2     13.4     22.9       0.6         12.0      12.3           13
# 1         2      7.4     25.1       0.0         12.0      12.3           14
# 2         2     12.9     25.7       0.0         12.0      12.3           15
# 3         2      9.2     28.0       0.0         12.0      12.3            4
# 4         2     17.5     32.3       1.0         12.0      12.3           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  WindSpeed3pm  Humidity9am  \
# 0           44.0          13          14  ...          24.0         71.0
# 1           44.0           6          15  ...          22.0         44.0
# 2           46.0          13          15  ...          26.0         38.0
# 3           24.0           9           0  ...           9.0         45.0
# 4           41.0           1           7  ...          20.0         82.0
#
# ...

# %% [markdown]
# Scaling the training data using standardscaler.

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
x_training1=scalar.fit_transform(X_training_data)

# %%
x_training2=pd.DataFrame(x_training1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x_training2,y_training_data,test_size=0.20,random_state=0)

# %% [markdown]
# Using LogisticRegression algorithm.

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression(solver='liblinear', random_state=0)
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %% [markdown]
# Predicting X_train and X_test values.

# %%
y_pred_train_training2=logreg.predict(X_train)
y_pred_train_training2
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_train,y_pred_train_training2)
# Out:
# 0.8413154702252228

# %%
y_pred_test_training2=logreg.predict(X_test)

# %%
accuracy_score(y_test,y_pred_test_training2)
# Out:
# 0.8427511515876086

# %%
logreg.predict_proba(X_train)[:,0]
# Out:
# array([0.80366615, 0.66634579, 0.99640935, ..., 0.90948562, 0.99237111,
#        0.61381711])

# %%
logreg.predict_proba(X_train)[:,1]
# Out:
# array([0.19633385, 0.33365421, 0.00359065, ..., 0.09051438, 0.00762889,
#        0.38618289])

# %%
#Saving Model
# loading library
import pickle
# create an iterator object with write permission - model.pkl
with open('model_pkl', 'wb') as files:
    pickle.dump(logreg, files)

# %%
df1_inference=df1.iloc[index_nan]
df1_inference
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 14       Albury      8.4     24.6       0.0          NaN       NaN
# 283      Albury      2.6      NaN       0.0          NaN       NaN
# 435      Albury     22.1     35.1       0.0          NaN       NaN
# 437      Albury     21.5     35.0       0.0          NaN       NaN
# 443      Albury     15.5     30.6       0.0          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 144955    Uluru     22.5     37.7       0.0          NaN       NaN
# 145091    Uluru     12.3     19.1       0.0          NaN       NaN
# 145092    Uluru     14.2     18.7       NaN          NaN       NaN
# 145335    Uluru     13.5      NaN       0.0          NaN       NaN
# 145459    Uluru     14.9      NaN       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 14             NaN            NaN          S        WNW  ...         57.0
# ...

# %%
X_inference_data=df1_inference.drop(["RainTomorrow"],axis=1)
y_inference_data=df1_inference["RainTomorrow"]

# %%
X_inference_data1=X_inference_data.fillna(method="ffill",axis=0)

# %%
X_inference_data2=X_inference_data1.fillna(method="bfill",axis=0)

# %%
from sklearn import preprocessing
L_encoding=preprocessing.LabelEncoder()
X_inference_data2['Location']=L_encoding.fit_transform(X_inference_data2['Location'])

# %%
X_inference_data2['WindGustDir']=L_encoding.fit_transform(X_inference_data2['WindGustDir'])

# %%
X_inference_data2['WindDir9am']=L_encoding.fit_transform(X_inference_data2['WindDir9am'])

# %%
X_inference_data2['WindDir3pm']=L_encoding.fit_transform(X_inference_data2['WindDir3pm'])

# %%
X_inference_data2['RainToday']=L_encoding.fit_transform(X_inference_data2['RainToday'])

# %%
X_inference_data2.head()
# Out:
#      Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 14          2      8.4     24.6       0.0          6.4       0.0            1
# 283         2      2.6     24.6       0.0          6.4       0.0            1
# 435         2     22.1     35.1       0.0          6.4       0.0            1
# 437         2     21.5     35.0       0.0          6.4       0.0            1
# 443         2     15.5     30.6       0.0          6.4       0.0            1
#
#      WindGustSpeed  WindDir9am  WindDir3pm  ...  WindSpeed3pm  Humidity9am  \
# 14            28.0           8          14  ...          30.0         57.0
# 283           28.0           0          14  ...          13.0         71.0
# 435           28.0           1          12  ...          11.0         58.0
# 437           28.0          10           0  ...           7.0         76.0
# 443           28.0           9          11  ...          11.0         66.0
#
# ...
